# %%
dict1={num:num*num for num in range(1,10)}
dict1
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
print(dict1[4])
print(dict1.keys())
# Out:
# 16
# dict_keys([1, 2, 3, 4, 5, 6, 7, 8, 9])

# %%
dict1[11]=121
dict1
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 11: 121}

# %%
dict1.pop(1)
# Out:
# 1

# %%
dict1
# Out:
# {2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 11: 121}

# %%
for i,j in dict1.items():
    print(f"{i} -> {j}")
# Out:
# 2 -> 4
# 3 -> 9
# 4 -> 16
# 5 -> 25
# 6 -> 36
# 7 -> 49
# 8 -> 64
# 9 -> 81
# 11 -> 121

# %%
dict2={num:num**3 for num in range(1,10) }
dict2
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125, 6: 216, 7: 343, 8: 512, 9: 729}

# %%
dict2
ll2=[(i,j) for i,j in dict1.items()]

# %%
ll2
# Out:
# [(2, 4),
#  (3, 9),
#  (4, 16),
#  (5, 25),
#  (6, 36),
#  (7, 49),
#  (8, 64),
#  (9, 81),
#  (11, 121)]

# %%
even=[(i,j) for i,j in dict1.items() if i%2 == 0]

# %%
even
# Out:
# [(2, 4), (4, 16), (6, 36), (8, 64)]

# %%
import json

mydict={
    "title":"my journey from barclays -> google/JPmorgan/faang",
    "author":"pinal",
    "year":2026
}
print(json.dumps(mydict))
# Out:
# {"title": "my journey from barclays -> google/JPmorgan/faang", "author": "pinal", "year": 2026}
