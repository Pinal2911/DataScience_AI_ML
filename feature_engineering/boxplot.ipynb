# %%
import numpy as np
lst_marks=[-1,-34,-100,22,12,33,45,23,12,67,44,32,78,65,88,54,78,66,34,88,153]

min,q1,median,q3,max=np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
min,q1,median,q3,max
# Out:
# (np.float64(-100.0),
#  np.float64(22.0),
#  np.float64(44.0),
#  np.float64(67.0),
#  np.float64(153.0))

# %%
IQR=q3-q1

# %%
IQR
# Out:
# np.float64(45.0)

# %%
lower_fence=q1-IQR
higher_fence=q1+IQR

# %%
lower_fence
# Out:
# np.float64(-23.0)

# %%
higher_fence
# Out:
# np.float64(67.0)

# %%
import seaborn as sns
sns.boxplot(lst_marks)
# Out:
# <Axes: >
