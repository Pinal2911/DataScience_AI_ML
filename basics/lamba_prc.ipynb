# %%
#sntax:
#lambda adgrs:exp

# %%
addition=lambda a,b:a+b
addition(5,6)
# Out:
# 11

# %%
even=lambda n:n%2==0
print(even(12))
print(even(65))
# Out:
# True
# False

# %%
#lambda with map sample examlple
nos=[1,2,3,4,5,6]
#apply sqaure lambda function to each number in nos (list)
sqre=map(lambda x:x**2,nos)
for i in sqre:
    print(i)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
