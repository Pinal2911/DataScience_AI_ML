# %%
s1=set()
s1={1,222,3333,222,45,3,87,54,90,22,67,45,89,87,44,92}

# %%
s1
# Out:
# {1, 3, 22, 44, 45, 54, 67, 87, 89, 90, 92, 222, 3333}

# %%
s1.add(11)

# %%
s1
# Out:
# {1, 3, 11, 22, 44, 45, 54, 67, 87, 89, 90, 92, 222, 3333}

# %%
s1.remove(1)

# %%
s1
# Out:
# {3, 11, 22, 44, 45, 54, 67, 87, 89, 90, 92, 222, 3333}

# %%
nums={1,2,3,4,5}
even={2,4,6,8,10}
nums
even
# Out:
# {2, 4, 6, 8, 10}

# %%
print(nums.intersection(even))
print(nums.union(even))
print(nums.difference(even))
print(nums.symmetric_difference(even))
# Out:
# {2, 4}
# {1, 2, 3, 4, 5, 6, 8, 10}
# {1, 3, 5}
# {1, 3, 5, 6, 8, 10}

# %%
s3=set(x**2 for x in range(10))
s3
# Out:
# {0, 1, 4, 9, 16, 25, 36, 49, 64, 81}

# %%
even_s4=set(x for x in range(10) if x%2==0)
even_s4
# Out:
# {0, 2, 4, 6, 8}

# %%
nums.issubset(even)
# Out:
# False

# %%
nums.issuperset(even)
# Out:
# False

# %%
even.issubset(nums)
# Out:
# False

# %%
even.issuperset(even_s4)
# Out:
# False

# %%
even_s4.issuperset(even)
# Out:
# False

# %%
even_s4.issubset(even)
# Out:
# False

# %%
s5=frozenset(even)
s5
# Out:
# frozenset({2, 4, 6, 8, 10})

# %%
my_dictionary = {
    frozenset(even): 10,
    frozenset(even_s4): 20,
}
my_dictionary
# Out:
# {frozenset({2, 4, 6, 8, 10}): 10, frozenset({0, 2, 4, 6, 8}): 20}

# %%
s6={(1,2),(3,4),(5,6),(7,8)}

# %%
s6
# Out:
# {(1, 2), (3, 4), (5, 6), (7, 8)}

# %%
for i in s6:
    print(type(i))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
